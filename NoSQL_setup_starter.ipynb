# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autos', 'config', 'espn', 'fruits_db', 'local', 'met', 'my_store', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66c14fc8ce83f52fd9551a19'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavours = { 'BusinessName': 'Penang Flavours','LocalAuthorityName':'Greenwich'}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(penang_flavours)
# Out:
# InsertOneResult(ObjectId('66c15037d87c4d0bdfd4d0b2'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query = {'BusinessName': 'Penang Flavours'}
results = establishments.find(query)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('66c15037d87c4d0bdfd4d0b2'), 'BusinessName': 'Penang Flavours', 'LocalAuthorityName': 'Greenwich'}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {}
fields = {'BusinessType': 1, 'BusinessTypeID':1}
results = establishments.find(query, fields)
for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a19')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a1a')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a1b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a1c')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a1e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a20')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a23')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a24')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a25')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a26')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a27')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a28')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a29')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a2d')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a2e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a2f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a30')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a31')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a32')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a33')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a34')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a35')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a37')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a38')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a3a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a3b')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a3c')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a3d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a3e')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a3f')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a40')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a41')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a42')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a43')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a44')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a45')}
# {'BusinessType': 'Distributors/Transporters',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a46')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a47')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a49')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a4a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a4b')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a4c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a4e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a4f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a51')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a52')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a53')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a54')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a55')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a56')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a58')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a59')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a5a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a5b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a5c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a5d')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a5e')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a5f')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a60')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a61')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a62')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a63')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a64')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a65')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a66')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a67')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a68')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a69')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a6a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a6b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a6c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a6d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a6e')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a6f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a70')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a71')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a72')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a73')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a74')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a75')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a76')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a77')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a78')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a79')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a7a')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a7b')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a7c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a7d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a7f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a80')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a81')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a82')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a83')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a84')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a86')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a87')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a88')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a89')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a8a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a8b')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a8c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a8d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a8e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a8f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a90')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a91')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a92')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a93')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a94')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a95')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a96')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a97')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a98')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a99')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a9c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a9d')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a9e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551a9f')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa0')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa1')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa5')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa8')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aa9')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aaa')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aab')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aac')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aae')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aaf')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab0')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab1')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab2')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab3')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab6')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab7')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab8')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ab9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aba')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551abb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551abc')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551abd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551abe')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551abf')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac0')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac2')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac4')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac6')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ac9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aca')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551acb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551acc')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551acd')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ace')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551acf')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad0')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad2')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad5')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad6')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad7')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad8')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ad9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ada')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551adb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551adc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551add')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ade')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551adf')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae0')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae2')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae5')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae6')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae7')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae8')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ae9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aea')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aeb')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aec')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aed')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aee')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af0')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af2')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af3')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af4')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af5')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af6')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af8')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551af9')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551afa')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551afb')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551afc')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551afd')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551afe')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551aff')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b00')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b01')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b02')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b03')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b05')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b06')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b09')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b0a')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b0b')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b0c')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b0d')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b0e')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b0f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b10')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b11')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b12')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b13')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b15')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b16')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b19')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b1a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b1b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b1c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b1e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b1f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b20')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b21')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b22')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b23')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b24')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b25')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b26')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b27')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b28')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b29')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b2c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b2d')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b2e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b2f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b30')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b31')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b32')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b33')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b34')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b35')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b37')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b38')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b39')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b3b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b3c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b3d')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b3e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b3f')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b40')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b41')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b42')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b43')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b44')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b45')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b46')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b47')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b48')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b49')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b4a')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b4b')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b4c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b4e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b4f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b50')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b51')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b52')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b53')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b54')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b55')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b56')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b57')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b58')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b59')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b5a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b5b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b5c')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b5d')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b5e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b5f')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b60')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b62')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b63')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b64')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b65')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b66')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b67')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b68')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b69')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b6a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b6b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b6c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b6e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b6f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b70')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b71')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b72')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b73')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b74')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b75')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b76')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b78')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b79')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b7a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b7b')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b7c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b7d')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b7e')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b7f')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b81')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b82')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b83')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b84')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b85')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b86')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b87')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b88')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b89')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b8a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b8b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b8c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b8d')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b8e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b8f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b90')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b91')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b92')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b95')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b96')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b97')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b98')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b9a')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b9b')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b9c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b9d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b9e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551b9f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba0')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba4')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba5')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba6')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba7')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba8')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551ba9')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551baa')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bab')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bac')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bad')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bae')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551baf')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb0')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb3')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb5')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb6')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb7')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb8')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bb9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bbb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bbc')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bbd')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bbe')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bbf')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bc0')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bc1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bc2')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bc3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fc8ce83f52fd9551bc4')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
# ...
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc2')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc3')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc4')}
# {'BusinessType': 'Distributors/Transporters',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc7')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cc9')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cca')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557ccb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557ccc')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557ccd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557ccf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd0')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd1')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd5')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd7')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cd9')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cda')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cdb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cdc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cdd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cde')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cdf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce2')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce3')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce5')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce6')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce7')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce8')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557ce9')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557cea')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557ceb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557ced')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cee')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cef')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf0')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf2')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf5')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf6')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cf9')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('66c14fcdce83f52fd9557cfa')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557cfb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557cfc')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557cfd')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cfe')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557cff')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557d00')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557d01')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d02')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d03')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d06')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fcdce83f52fd9557d07')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d08')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557d09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d0a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d0d')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fcdce83f52fd9557d0e')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fcdce83f52fd9557d0f')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fcdce83f52fd9557d10')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557d11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d12')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d13')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557d14')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d15')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d16')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d18')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('66c14fcdce83f52fd9557d19')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d1a')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557d1b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d1c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d1d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557d1e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557d1f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557d20')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557d21')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d22')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557d23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d24')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('66c14fcdce83f52fd9557d25')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557d26')}
# {'BusinessType': 'Distributors/Transporters',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('66c14fcdce83f52fd9557d27')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d28')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557d29')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d2d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d2e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d2f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d30')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d31')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557d32')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d33')}
# {'BusinessType': 'Distributors/Transporters',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('66c14fcdce83f52fd9557d34')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557d35')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('66c14fcdce83f52fd9557d36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d37')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d38')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557d39')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557d3a')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fcdce83f52fd9557d3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d3c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d3d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d3e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d3f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d40')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d41')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557d42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d43')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d44')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d45')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('66c14fcdce83f52fd9557d46')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fcdce83f52fd9557d47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d48')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('66c14fcdce83f52fd9557d49')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('66c14fcdce83f52fd9557d4a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('66c14fcdce83f52fd9557d4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66c14fcdce83f52fd9557d4c')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('66c14fcdce83f52fd9557d4d')}
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
    {'BusinessName': 'Penang Flavours'},
    {'$set': {
        'BusinessType':'Restaurant/Cafe/Canteen','Restaurant/Cafe/Canteen':1}
    })
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': 'Penang Flavours'}
results = establishments.find(query)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('66c15037d87c4d0bdfd4d0b2'), 'BusinessName': 'Penang Flavours', 'LocalAuthorityName': 'Greenwich', 'BusinessType': 'Restaurant/Cafe/Canteen', 'Restaurant/Cafe/Canteen': 1}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': "Dover"}
print(establishments.count_documents(query))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': "Dover"}
print(establishments.count_documents(query))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66c14fc8ce83f52fd9551d00'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set':
                                  { "geocode.longitude" : {'$toDouble': "$geocode.longitude"}}} ])
establishments.update_many({}, [ {'$set':
                                  { "geocode.latitude" : {'$toDouble': "$geocode.latitude"}}} ])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38785, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ {'$set':
                                  { "RatingValue" : {'$toDouble': "$RatingValue"}}} ])
# Out:
# UpdateResult({'n': 38786, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5.0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66c14fc8ce83f52fd9551d00'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
